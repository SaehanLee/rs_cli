# %%
from datetime import date, datetime

def get_column_datatype(cell):
    """
    Gets the Redshift datatype for a column in the csv
    
    type cell: can be one of the following types:
        int, decimal, float, 
    """ 
    #subfunction checking if a cell is a float or not
    def _isfloat(s):
        try:
            float(s)
            return True
        except ValueError:
            return False
    
    #subfunction checking if a cell is a bool or not
    #NOTE: if a cell has a bool datatype then it must be
    #      initially recorded with capital 'T' for 'True' or capital 'F' for 'False'
    def _isbool(s):
        if s=='True' or s=='False':
            return True
        else:
            return False
    
    #subfunction checking if a cell is a date or not
    #NOTE: this subfunction only accounts for two different date formats
    #      from the CSV. 
    #      Format One: 8 digits, where the first 4
    #          digits represent year, then next 2 digits represent month, and
    #          final two digits represent day
    #      Format Two: 2 digits for day of the month followed by
    #          string of 3 letters representing month (first 3 letters of month name)
    #          followed by 4 digits for year
    def _isdate(s):
        #Format One check
        if s.isdigit() and len(s)==8:
            potential_year = int(s[:4].lstrip('0'))
            potential_month = int(s[4:6].lstrip('0'))
            potential_day = int(s[6:].lstrip('0'))
            if potential_year in range(0,2016) and potential_month in range(1,12) \
                and potential_day in range(1,31):
                    return True             
        #Format Two check
        if len(s)==9:
            potential_year2 = int(s[5:].lstrip('0'))
            potential_day2 = int(s[:2].lstrip('0'))
            #checking if 3 letters in the middle of the string represent a valid month
            if s[2:5] in ('JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', \
                'JUL', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC') and potential_year2 in range(0,2016) \
                and potential_day2 in range(1,31):
                    return True
        #if neither Format One of Format Two
        return False
    
    #strip of all white space before anf after the string
    cell = cell.strip(' ')
    if _isdate(cell):
        return 'date'
    elif cell.isdigit():
        return 'integer'
    elif _isfloat(cell):
        return 'real'
    elif _isbool(cell):
        return 'bool'
    else:
        return 'varchar(256)'

# %%
#INPUT : SOME CSV FILE
#OUTPUT: SQL QUERY TO CREATE THE TABLE ITSELF IN REDSHIFT
        # AND SQL QUERY TO POPULATE TABLE

import csv
    
def get_query_from_csv(some_csv):
    with open(some_csv, 'r') as f:
        reader = csv.reader(f)
        csv_rows_list = list(reader)
        
    headers = csv_rows_list[0] #your headers for each of the columns
    columns_datatypes_list = [get_column_datatype(column_cell) for column_cell in csv_rows_list[1]]  
    
    column_headers_and_types = \
        ', '.join([headers[i] + " " + columns_datatypes_list[i] for i in range(0, len(headers))])
    
    table_name, csv_ext = some_csv.split('.')
    final_query = "CREATE TABLE IF NOT EXISTS " + table_name + " (" + \
        column_headers_and_types + ")"
    
    print(csv_rows_list)
    
    return final_query

# %%
a_data = get_query_from_csv("sample.csv")
# Out:
# [['head1', 'head2', 'head3', 'head4'], ['1', ' 2', ' 3.0', ' 19310810'], ['4', ' 5', ' 6.0', ' 10MAR2010'], ['7', ' 8', ' 9.0', ' 09MAR2010'], ['10', ' 11', ' 12.0', ' 09MAR2010'], ['13', ' 14', ' 15.0', ' 09MAR2010']]

# %%
a_data
# Out:
# 'CREATE TABLE IF NOT EXISTS sample (head1 integer, head2 integer, head3 real, head4 date)'

# %%
import pandas as pd

# %%
df = pd.read_csv("sample.csv")

# %%
df.columns.values
# Out:
# array(['head1', 'head2', 'head3', 'head4'], dtype=object)

# %%
df
# Out:
#    head1  head2  head3       head4
# 0      1      2      3    19310810
# 1      4      5      6   10MAR2010
# 2      7      8      9   09MAR2010
# 3     10     11     12   09MAR2010
# 4     13     14     15   09MAR2010

# %%
def funcA(x):
    return x*x

# %%
df['head1'] = df[['head1']].apply(funcA)

# %%
df.dtypes
# Out:
# head1      int64
# head2      int64
# head3    float64
# head4     object
# dtype: object

# %%
for thing in df:
    print(df[thing][0])
# Out:
# 1
# 2
# 3.0
#  19310810

# %%
def _isdate(s):
    #Format One check
    if s.isdigit() and len(s)==8:
        potential_year = int(s[:4].lstrip('0'))
        potential_month = int(s[4:6].lstrip('0'))
        potential_day = int(s[6:].lstrip('0'))
        if potential_year in range(0,2016) and potential_month in range(1,12) \
            and potential_day in range(1,31):
                return True             
    #Format Two check
    if len(s)==9:
        potential_year2 = int(s[5:].lstrip('0'))
        potential_day2 = int(s[:2].lstrip('0'))
        #checking if 3 letters in the middle of the string represent a valid month
        if s[2:5] in ('JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', \
            'JUL', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC') and potential_year2 in range(0,2016) \
            and potential_day2 in range(1,31):
                return True
    #if neither Format One of Format Two
    return False

# %%
df = pd.read_csv('/Users/jlee/Downloads/COTA_Health_Claims_19.txt', delimiter='|')
# Out:
# /Users/jlee/.pyenv/versions/3.4.3/lib/python3.4/site-packages/IPython/core/interactiveshell.py:2723: DtypeWarning: Columns (0,10,13,14,22,26,27,29,30,33,43,61,64,67,68,69,71,72,73,74,75,76,77,81,82) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head(100)
# Out:
#      CLM_SRC_ID CLM_SRC_SYS_CD  CLM_LN_SRC_ID    MAIN MAJ_PROD        HZN_ID  \
# 0   10152002890            QMX              1  055272      HMO  3HZN18936880
# 1   10186000418            QMX              1  055272      HMO  3HZN18936880
# 2   10265001223            QMX              1  055272      HMO  3HZN18936880
# 3   10266001485            QMX              1  055272      HMO  3HZN18936880
# 4   10280001287            QMX              1  055272      HMO  3HZN18936880
# 5   10295001426            QMX              1  055272      HMO  3HZN18936880
# 6   10298002426            QMX              1  055272      HMO  3HZN18936880
# 7   10300001308            QMX              1  055272      HMO  3HZN18936880
# 8   10314A02090            QMX              1  00003Y      HMO  3HZN01254460
# 9   10314A02090            QMX              2  00003Y      HMO  3HZN01254460
# 10  10314A02090            QMX              3  00003Y      HMO  3HZN01254460
# 11  10314A02090            QMX              4  00003Y      HMO  3HZN01254460
# 12  10314A02090            QMX              5  00003Y      HMO  3HZN01254460
# 13  10314A02090            QMX              6  00003Y      HMO  3HZN01254460
# 14  10314A02090            QMX              7  00003Y      HMO  3HZN01254460
# 15  10314A02090            QMX              8  00003Y      HMO  3HZN01254460
# 16  10314A02090            QMX              9  00003Y      HMO  3HZN01254460
# 17  10314A02090            QMX             10  00003Y      HMO  3HZN01254460
# 18  10314A02090            QMX             11  00003Y      HMO  3HZN01254460
# 19  10314A02090            QMX             12  00003Y      HMO  3HZN01254460
# 20  10314A02090            QMX             13  00003Y      HMO  3HZN01254460
# 21  10314A02090            QMX             14  00003Y      HMO  3HZN01254460
# 22  10314A02090            QMX             15  00003Y      HMO  3HZN01254460
# 23  10314A02090            QMX             16  00003Y      HMO  3HZN01254460
# 24  10316001569            QMX              1  055272      HMO  3HZN18936880
# 25  10321A01656            QMX              1  NG0001      HMO  3HZN43930420
# 26  10321A01656            QMX              2  NG0001      HMO  3HZN43930420
# 27  10321A01656            QMX              3  NG0001      HMO  3HZN43930420
# 28  10321A01656            QMX              4  NG0001      HMO  3HZN43930420
# 29  10321A01656            QMX              5  NG0001      HMO  3HZN43930420
# ..          ...            ...            ...     ...      ...           ...
# 70   1032401320            QMX             10  087471    INDEM  3HZN19635160
# 71   1032401320            QMX             11  087471    INDEM  3HZN19635160
# 72   1032401349            QMX             10  087471    INDEM  3HZN19635160
# 73   1032401349            QMX             11  087471    INDEM  3HZN19635160
# 74   1032401378            QMX             10  087471    INDEM  3HZN19635160
# 75   1032401378            QMX             11  087471    INDEM  3HZN19635160
# 76   1032401795            QMX             10  087471    INDEM  3HZN19635160
# 77   1032401795            QMX             20  087471    INDEM  3HZN19635160
# 78   1032401795            QMX             21  087471    INDEM  3HZN19635160
# 79   1032401795            QMX             30  087471    INDEM  3HZN19635160
# 80   1032401795            QMX             31  087471    INDEM  3HZN19635160
# 81   1034102763            QMX             10  087471    INDEM  3HZN19635160
# 82   1034102763            QMX             20  087471    INDEM  3HZN19635160
# 83   1034102763            QMX             30  087471    INDEM  3HZN19635160
# 84   1034102763            QMX             40  087471    INDEM  3HZN19635160
# 85   1034102763            QMX             41  087471    INDEM  3HZN19635160
# 86   1034102763            QMX             50  087471    INDEM  3HZN19635160
# 87   1034102763            QMX             51  087471    INDEM  3HZN19635160
# 88   1034102763            QMX             60  087471    INDEM  3HZN19635160
# 89   1034102763            QMX             61  087471    INDEM  3HZN19635160
# 90   1034102763            QMX             70  087471    INDEM  3HZN19635160
# 91   1034102763            QMX             71  087471    INDEM  3HZN19635160
# 92   1034102763            QMX             80  087471    INDEM  3HZN19635160
# 93   1034102763            QMX             81  087471    INDEM  3HZN19635160
# 94   1034102763            QMX             90  087471    INDEM  3HZN19635160
# 95   1034102763            QMX             91  087471    INDEM  3HZN19635160
# 96   1034102763            QMX            100  087471    INDEM  3HZN19635160
# 97   1034102763            QMX            101  087471    INDEM  3HZN19635160
# 98   1034102763            QMX            110  087471    INDEM  3HZN19635160
# 99   1034102763            QMX            120  087471    INDEM  3HZN19635160
#
#     SUBS_ID PAT_FNM   PAT_LNM PAT_REL       ...        IN_OUT_IND  \
# 0       NaN     NaN       NaN    SELF       ...                IN
# 1       NaN     NaN       NaN    SELF       ...                IN
# 2       NaN     NaN       NaN    SELF       ...                IN
# 3       NaN     NaN       NaN    SELF       ...                IN
# 4       NaN     NaN       NaN    SELF       ...                IN
# 5       NaN     NaN       NaN    SELF       ...                IN
# 6       NaN     NaN       NaN    SELF       ...                IN
# 7       NaN     NaN       NaN    SELF       ...                IN
# 8       NaN   MOLLY  SHEPHERD    SELF       ...                IN
# 9       NaN   MOLLY  SHEPHERD    SELF       ...                IN
# 10      NaN   MOLLY  SHEPHERD    SELF       ...                IN
# 11      NaN   MOLLY  SHEPHERD    SELF       ...                IN
# 12      NaN   MOLLY  SHEPHERD    SELF       ...                IN
# 13      NaN   MOLLY  SHEPHERD    SELF       ...                IN
# 14      NaN   MOLLY  SHEPHERD    SELF       ...                IN
# 15      NaN   MOLLY  SHEPHERD    SELF       ...                IN
# 16      NaN   MOLLY  SHEPHERD    SELF       ...                IN
# 17      NaN   MOLLY  SHEPHERD    SELF       ...                IN
# 18      NaN   MOLLY  SHEPHERD    SELF       ...                IN
# 19      NaN   MOLLY  SHEPHERD    SELF       ...                IN
# 20      NaN   MOLLY  SHEPHERD    SELF       ...                IN
# 21      NaN   MOLLY  SHEPHERD    SELF       ...                IN
# 22      NaN   MOLLY  SHEPHERD    SELF       ...                IN
# 23      NaN   MOLLY  SHEPHERD    SELF       ...                IN
# 24      NaN     NaN       NaN    SELF       ...                IN
# 25      NaN     NaN       NaN    SELF       ...                IN
# 26      NaN     NaN       NaN    SELF       ...                IN
# 27      NaN     NaN       NaN    SELF       ...                IN
# 28      NaN     NaN       NaN    SELF       ...                IN
# 29      NaN     NaN       NaN    SELF       ...                IN
# ..      ...     ...       ...     ...       ...               ...
# 70      NaN     NaN       NaN    SELF       ...                IN
# 71      NaN     NaN       NaN    SELF       ...                IN
# 72      NaN     NaN       NaN    SELF       ...                IN
# 73      NaN     NaN       NaN    SELF       ...                IN
# 74      NaN     NaN       NaN    SELF       ...                IN
# 75      NaN     NaN       NaN    SELF       ...                IN
# 76      NaN     NaN       NaN    SELF       ...                IN
# 77      NaN     NaN       NaN    SELF       ...                IN
# 78      NaN     NaN       NaN    SELF       ...                IN
# 79      NaN     NaN       NaN    SELF       ...                IN
# 80      NaN     NaN       NaN    SELF       ...                IN
# 81      NaN     NaN       NaN    SELF       ...                IN
# 82      NaN     NaN       NaN    SELF       ...                IN
# 83      NaN     NaN       NaN    SELF       ...                IN
# 84      NaN     NaN       NaN    SELF       ...                IN
# 85      NaN     NaN       NaN    SELF       ...                IN
# 86      NaN     NaN       NaN    SELF       ...                IN
# 87      NaN     NaN       NaN    SELF       ...                IN
# 88      NaN     NaN       NaN    SELF       ...                IN
# 89      NaN     NaN       NaN    SELF       ...                IN
# 90      NaN     NaN       NaN    SELF       ...                IN
# 91      NaN     NaN       NaN    SELF       ...                IN
# 92      NaN     NaN       NaN    SELF       ...                IN
# 93      NaN     NaN       NaN    SELF       ...                IN
# 94      NaN     NaN       NaN    SELF       ...                IN
# 95      NaN     NaN       NaN    SELF       ...                IN
# 96      NaN     NaN       NaN    SELF       ...                IN
# 97      NaN     NaN       NaN    SELF       ...                IN
# 98      NaN     NaN       NaN    SELF       ...                IN
# 99      NaN     NaN       NaN    SELF       ...                IN
#
#    IND_REND_TIN REND_FIRST_NAME REND_LAST_NAME                 hznkey  \
# 0           NaN             NaN            NaN                    NaN
# 1           NaN             NaN            NaN                    NaN
# 2           NaN             NaN            NaN                    NaN
# 3           NaN             NaN            NaN                    NaN
# 4           NaN             NaN            NaN                    NaN
# 5           NaN             NaN            NaN                    NaN
# 6           NaN             NaN            NaN                    NaN
# 7           NaN             NaN            NaN                    NaN
# 8           NaN             NaN            NaN  3HZN01254460MOL-16621
# 9           NaN             NaN            NaN  3HZN01254460MOL-16621
# 10          NaN             NaN            NaN  3HZN01254460MOL-16621
# 11          NaN             NaN            NaN  3HZN01254460MOL-16621
# 12          NaN             NaN            NaN  3HZN01254460MOL-16621
# 13          NaN             NaN            NaN  3HZN01254460MOL-16621
# 14          NaN             NaN            NaN  3HZN01254460MOL-16621
# 15          NaN             NaN            NaN  3HZN01254460MOL-16621
# 16          NaN             NaN            NaN  3HZN01254460MOL-16621
# 17          NaN             NaN            NaN  3HZN01254460MOL-16621
# 18          NaN             NaN            NaN  3HZN01254460MOL-16621
# 19          NaN             NaN            NaN  3HZN01254460MOL-16621
# 20          NaN             NaN            NaN  3HZN01254460MOL-16621
# 21          NaN             NaN            NaN  3HZN01254460MOL-16621
# 22          NaN             NaN            NaN  3HZN01254460MOL-16621
# 23          NaN             NaN            NaN  3HZN01254460MOL-16621
# 24          NaN             NaN            NaN                    NaN
# 25          NaN             NaN            NaN                    NaN
# 26          NaN             NaN            NaN                    NaN
# 27          NaN             NaN            NaN                    NaN
# 28          NaN             NaN            NaN                    NaN
# 29          NaN             NaN            NaN                    NaN
# ..          ...             ...            ...                    ...
# 70          NaN             NaN            NaN                    NaN
# 71          NaN             NaN            NaN                    NaN
# 72          NaN             NaN            NaN                    NaN
# 73          NaN             NaN            NaN                    NaN
# 74          NaN             NaN            NaN                    NaN
# 75          NaN             NaN            NaN                    NaN
# 76          NaN             NaN            NaN                    NaN
# 77          NaN             NaN            NaN                    NaN
# 78          NaN             NaN            NaN                    NaN
# 79          NaN             NaN            NaN                    NaN
# 80          NaN             NaN            NaN                    NaN
# 81          NaN             NaN            NaN                    NaN
# 82          NaN             NaN            NaN                    NaN
# 83          NaN             NaN            NaN                    NaN
# 84          NaN             NaN            NaN                    NaN
# 85          NaN             NaN            NaN                    NaN
# 86          NaN             NaN            NaN                    NaN
# 87          NaN             NaN            NaN                    NaN
# 88          NaN             NaN            NaN                    NaN
# 89          NaN             NaN            NaN                    NaN
# 90          NaN             NaN            NaN                    NaN
# 91          NaN             NaN            NaN                    NaN
# 92          NaN             NaN            NaN                    NaN
# 93          NaN             NaN            NaN                    NaN
# 94          NaN             NaN            NaN                    NaN
# 95          NaN             NaN            NaN                    NaN
# 96          NaN             NaN            NaN                    NaN
# 97          NaN             NaN            NaN                    NaN
# 98          NaN             NaN            NaN                    NaN
# 99          NaN             NaN            NaN                    NaN
#
#     ICD_VER_CD mask_it        efdt       trmdt CANCER_DIAG_FDOS
# 0            9       Y  05/20/2006  05/19/2014        11JAN2012
# 1            9       Y  05/20/2006  05/19/2014        11JAN2012
# 2            9       Y  05/20/2006  05/19/2014        11JAN2012
# 3            9       Y  05/20/2006  05/19/2014        11JAN2012
# 4            9       Y  05/20/2006  05/19/2014        11JAN2012
# 5            9       Y  05/20/2006  05/19/2014        11JAN2012
# 6            9       Y  05/20/2006  05/19/2014        11JAN2012
# 7            9       Y  05/20/2006  05/19/2014        11JAN2012
# 8            9       N  01/01/2011  12/31/2013        08MAR2012
# 9            9       N  01/01/2011  12/31/2013        08MAR2012
# 10           9       N  01/01/2011  12/31/2013        08MAR2012
# 11           9       N  01/01/2011  12/31/2013        08MAR2012
# 12           9       N  01/01/2011  12/31/2013        08MAR2012
# 13           9       N  01/01/2011  12/31/2013        08MAR2012
# 14           9       N  01/01/2011  12/31/2013        08MAR2012
# 15           9       N  01/01/2011  12/31/2013        08MAR2012
# 16           9       N  01/01/2011  12/31/2013        08MAR2012
# 17           9       N  01/01/2011  12/31/2013        08MAR2012
# 18           9       N  01/01/2011  12/31/2013        08MAR2012
# 19           9       N  01/01/2011  12/31/2013        08MAR2012
# 20           9       N  01/01/2011  12/31/2013        08MAR2012
# 21           9       N  01/01/2011  12/31/2013        08MAR2012
# 22           9       N  01/01/2011  12/31/2013        08MAR2012
# 23           9       N  01/01/2011  12/31/2013        08MAR2012
# 24           9       Y  05/20/2006  05/19/2014        11JAN2012
# 25           9       Y  08/01/2006  07/31/2014        10JAN2012
# 26           9       Y  08/01/2006  07/31/2014        10JAN2012
# 27           9       Y  08/01/2006  07/31/2014        10JAN2012
# 28           9       Y  08/01/2006  07/31/2014        10JAN2012
# 29           9       Y  08/01/2006  07/31/2014        10JAN2012
# ..         ...     ...         ...         ...              ...
# 70           9       Y  04/01/1999  12/31/9999        11JAN2012
# 71           9       Y  04/01/1999  12/31/9999        11JAN2012
# 72           9       Y  04/01/1999  12/31/9999        11JAN2012
# 73           9       Y  04/01/1999  12/31/9999        11JAN2012
# 74           9       Y  04/01/1999  12/31/9999        11JAN2012
# 75           9       Y  04/01/1999  12/31/9999        11JAN2012
# 76           9       Y  04/01/1999  12/31/9999        11JAN2012
# 77           9       Y  04/01/1999  12/31/9999        11JAN2012
# 78           9       Y  04/01/1999  12/31/9999        11JAN2012
# 79           9       Y  04/01/1999  12/31/9999        11JAN2012
# 80           9       Y  04/01/1999  12/31/9999        11JAN2012
# 81           9       Y  04/01/1999  12/31/9999        11JAN2012
# 82           9       Y  04/01/1999  12/31/9999        11JAN2012
# 83           9       Y  04/01/1999  12/31/9999        11JAN2012
# 84           9       Y  04/01/1999  12/31/9999        11JAN2012
# 85           9       Y  04/01/1999  12/31/9999        11JAN2012
# 86           9       Y  04/01/1999  12/31/9999        11JAN2012
# 87           9       Y  04/01/1999  12/31/9999        11JAN2012
# 88           9       Y  04/01/1999  12/31/9999        11JAN2012
# 89           9       Y  04/01/1999  12/31/9999        11JAN2012
# 90           9       Y  04/01/1999  12/31/9999        11JAN2012
# 91           9       Y  04/01/1999  12/31/9999        11JAN2012
# 92           9       Y  04/01/1999  12/31/9999        11JAN2012
# 93           9       Y  04/01/1999  12/31/9999        11JAN2012
# 94           9       Y  04/01/1999  12/31/9999        11JAN2012
# 95           9       Y  04/01/1999  12/31/9999        11JAN2012
# 96           9       Y  04/01/1999  12/31/9999        11JAN2012
# 97           9       Y  04/01/1999  12/31/9999        11JAN2012
# 98           9       Y  04/01/1999  12/31/9999        11JAN2012
# 99           9       Y  04/01/1999  12/31/9999        11JAN2012
#
# [100 rows x 89 columns]

# %%
df.head(100)['trmdt'].apply(_isdate)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
#       ...
# 70    False
# 71    False
# 72    False
# 73    False
# 74    False
# 75    False
# 76    False
# 77    False
# 78    False
# 79    False
# 80    False
# 81    False
# 82    False
# 83    False
# 84    False
# 85    False
# 86    False
# 87    False
# 88    False
# 89    False
# 90    False
# 91    False
# 92    False
# 93    False
# 94    False
# 95    False
# 96    False
# 97    False
# 98    False
# 99    False
# Name: trmdt, dtype: bool

# %%
df.head(100)['CANCER_DIAG_FDOS'].apply(_isdate)
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# 10    True
# 11    True
# 12    True
# 13    True
# 14    True
# 15    True
# 16    True
# 17    True
# 18    True
# 19    True
# 20    True
# 21    True
# 22    True
# 23    True
# 24    True
# 25    True
# 26    True
# 27    True
# 28    True
# 29    True
#       ...
# 70    True
# 71    True
# 72    True
# 73    True
# 74    True
# 75    True
# 76    True
# 77    True
# 78    True
# 79    True
# 80    True
# 81    True
# 82    True
# 83    True
# 84    True
# 85    True
# 86    True
# 87    True
# 88    True
# 89    True
# 90    True
# 91    True
# 92    True
# 93    True
# 94    True
# 95    True
# 96    True
# 97    True
# 98    True
# 99    True
# Name: CANCER_DIAG_FDOS, dtype: bool

# %%
df[['head4']]
# Out:
#         head4
# 0    19310810
# 1   10MAR2010
# 2   09MAR2010
# 3   09MAR2010
# 4   09MAR2010

# %%
df
# Out:
#    head1  head2  head3       head4
# 0      1      2      3    19310810
# 1     16      5      6   10MAR2010
# 2     49      8      9   09MAR2010
# 3    100     11     12   09MAR2010
# 4    169     14     15   09MAR2010

# %%
# Out:
# True

# %%
a_data
# Out:
# 'CREATE TABLE IF NOT EXISTS sample (head1 integer, head2 integer, head3 real, head4 date)'

# %%
a_data
# Out:
# 'CREATE TABLE IF NOT EXISTS sample (head1 integer, head2 integer, head3 real, head4 date)'
